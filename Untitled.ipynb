# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker

# %%
api_key = 'AIzaSyDQ-X7Xj1-d3rr4Mj9t8WqcyOA9YGjaMdE'

# %%
channel_ids = ['UCrfaLdVUAziZq9_yRFKYuIQ']

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    # loop throught items
    for item in response['items']:
        data = {'channelName':item['snippet']['title'],
        'subscribers':item['statistics']['subscriberCount'],
        'views':item['statistics']['viewCount'],
        'totalViews':item['statistics']['videoCount'],
        'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)

    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#     channelName subscribers     views totalViews                playlistId
# 0  Drama Master      441000  86673716        164  UUrfaLdVUAziZq9_yRFKYuIQ

# %%
playlist_id = channel_stats['playlistId'][0]

def get_video_ids(youtube, playlist_id):
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults = 50,
            pageToken = next_page_token)
        response = request.execute()
    
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
    
        next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 164

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []
    
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=video_ids[0:5]
    )
    response = request.execute()

    for video in response['items']:
        stats_to_keep = {'snippet' : ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                        'statistics' : ['viewCount', 'likeCount', 'favouritecounut', 'commentCount'],
                        'contentDetails': ['duration', 'definition', 'caption']
                        }

        video_info = {}
        video_info['video_id'] = video['id']

        for k in stats_to_keep.keys():
            for v in stats_to_keep[k]:
                try:
                    video_info[v] = video[k][v]
                except:
                    video_info[v] = None
        all_video_info.append(video_info)
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#       video_id  channelTitle  \
# 0  lEAuk94_0L0  Drama Master
# 1  cA_YIi0wavo  Drama Master
# 2  Y1VxrixgR60  Drama Master
# 3  _ZqEYv47o0E  Drama Master
# 4  c8CwQSiJtEg  Drama Master
#
#                                                title  \
# 0                         Wife and Husband of Kdrama
# 1                         The adult life by k-dramas
# 2                        Kdrama : Use of smartphones
# 3                          Kdrama : Partner in crime
# 4  Kdrama : Red flag and Green flag in a relation...
#
#                                          description  tags  \
# 0  Drama names are available in the video, commen...  None
# 1  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 2  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 3  Drama names are available in the video, commen...  None
# 4  Drama names are available in the video, commen...  None
#
#             publishedAt viewCount likeCount favouritecounut commentCount  \
# 0  2022-10-07T12:30:16Z    176024     12042            None          435
# 1  2022-09-30T12:30:20Z    166143     12898            None          487
# 2  2022-09-23T12:30:09Z    136658     11198            None          497
# 3  2022-09-16T12:30:11Z    186330     14375            None          552
# 4  2022-09-09T12:30:10Z    474419     31398            None          868
#
#   duration definition caption
# 0  PT5M24S         hd   false
# 1  PT6M12S         hd   false
# 2   PT6M6S         hd   false
# 3  PT5M25S         hd   false
# 4  PT5M33S         hd   false

# %%
video_df.isnull().any()
# Out:
# video_id           False
# channelTitle       False
# title              False
# description        False
# tags                True
# publishedAt        False
# viewCount          False
# likeCount          False
# favouritecounut     True
# commentCount       False
# duration           False
# definition         False
# caption            False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount          object
# likeCount          object
# favouritecounut    object
# commentCount       object
# duration           object
# definition         object
# caption            object
# dtype: object

# %%
# fix data types
numeric_cols = ['viewCount', 'likeCount', 'favouritecounut', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# publish day in the week
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'])
video_df['publishedDayName'] = video_df['publishedAt'].dt.day_name()

# %%
video_df
# Out:
#       video_id  channelTitle  \
# 0  lEAuk94_0L0  Drama Master
# 1  cA_YIi0wavo  Drama Master
# 2  Y1VxrixgR60  Drama Master
# 3  _ZqEYv47o0E  Drama Master
# 4  c8CwQSiJtEg  Drama Master
#
#                                                title  \
# 0                         Wife and Husband of Kdrama
# 1                         The adult life by k-dramas
# 2                        Kdrama : Use of smartphones
# 3                          Kdrama : Partner in crime
# 4  Kdrama : Red flag and Green flag in a relation...
#
#                                          description  tags  \
# 0  Drama names are available in the video, commen...  None
# 1  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 2  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 3  Drama names are available in the video, commen...  None
# 4  Drama names are available in the video, commen...  None
#
#                 publishedAt  viewCount  likeCount  favouritecounut  \
# 0 2022-10-07 12:30:16+00:00   176024.0    12042.0              NaN
# 1 2022-09-30 12:30:20+00:00   166143.0    12898.0              NaN
# 2 2022-09-23 12:30:09+00:00   136658.0    11198.0              NaN
# 3 2022-09-16 12:30:11+00:00   186330.0    14375.0              NaN
# 4 2022-09-09 12:30:10+00:00   474419.0    31398.0              NaN
#
#    commentCount duration definition caption publishedDayName
# 0         435.0  PT5M24S         hd   false           Friday
# 1         487.0  PT6M12S         hd   false           Friday
# 2         497.0   PT6M6S         hd   false           Friday
# 3         552.0  PT5M25S         hd   false           Friday
# 4         868.0  PT5M33S         hd   false           Friday

# %%
# convert youtube duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df
# Out:
#       video_id  channelTitle  \
# 0  lEAuk94_0L0  Drama Master
# 1  cA_YIi0wavo  Drama Master
# 2  Y1VxrixgR60  Drama Master
# 3  _ZqEYv47o0E  Drama Master
# 4  c8CwQSiJtEg  Drama Master
#
#                                                title  \
# 0                         Wife and Husband of Kdrama
# 1                         The adult life by k-dramas
# 2                        Kdrama : Use of smartphones
# 3                          Kdrama : Partner in crime
# 4  Kdrama : Red flag and Green flag in a relation...
#
#                                          description  tags  \
# 0  Drama names are available in the video, commen...  None
# 1  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 2  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 3  Drama names are available in the video, commen...  None
# 4  Drama names are available in the video, commen...  None
#
#                 publishedAt  viewCount  likeCount  favouritecounut  \
# 0 2022-10-07 12:30:16+00:00   176024.0    12042.0              NaN
# 1 2022-09-30 12:30:20+00:00   166143.0    12898.0              NaN
# 2 2022-09-23 12:30:09+00:00   136658.0    11198.0              NaN
# 3 2022-09-16 12:30:11+00:00   186330.0    14375.0              NaN
# 4 2022-09-09 12:30:10+00:00   474419.0    31398.0              NaN
#
#    commentCount duration definition caption publishedDayName    durationSecs
# 0         435.0  PT5M24S         hd   false           Friday 0 days 00:05:24
# 1         487.0  PT6M12S         hd   false           Friday 0 days 00:06:12
# 2         497.0   PT6M6S         hd   false           Friday 0 days 00:06:06
# 3         552.0  PT5M25S         hd   false           Friday 0 days 00:05:25
# 4         868.0  PT5M33S         hd   false           Friday 0 days 00:05:33

# %%
# Add number of tags
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))
video_df
# Out:
#       video_id  channelTitle  \
# 0  lEAuk94_0L0  Drama Master
# 1  cA_YIi0wavo  Drama Master
# 2  Y1VxrixgR60  Drama Master
# 3  _ZqEYv47o0E  Drama Master
# 4  c8CwQSiJtEg  Drama Master
#
#                                                title  \
# 0                         Wife and Husband of Kdrama
# 1                         The adult life by k-dramas
# 2                        Kdrama : Use of smartphones
# 3                          Kdrama : Partner in crime
# 4  Kdrama : Red flag and Green flag in a relation...
#
#                                          description  tags  \
# 0  Drama names are available in the video, commen...  None
# 1  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 2  Visit Fashion Chingu for Kdrama and kpop recre...  None
# 3  Drama names are available in the video, commen...  None
# 4  Drama names are available in the video, commen...  None
#
#                 publishedAt  viewCount  likeCount  favouritecounut  \
# 0 2022-10-07 12:30:16+00:00   176024.0    12042.0              NaN
# 1 2022-09-30 12:30:20+00:00   166143.0    12898.0              NaN
# 2 2022-09-23 12:30:09+00:00   136658.0    11198.0              NaN
# 3 2022-09-16 12:30:11+00:00   186330.0    14375.0              NaN
# 4 2022-09-09 12:30:10+00:00   474419.0    31398.0              NaN
#
#    commentCount duration definition caption publishedDayName    durationSecs  \
# 0         435.0  PT5M24S         hd   false           Friday 0 days 00:05:24
# 1         487.0  PT6M12S         hd   false           Friday 0 days 00:06:12
# 2         497.0   PT6M6S         hd   false           Friday 0 days 00:06:06
# 3         552.0  PT5M25S         hd   false           Friday 0 days 00:05:25
# 4         868.0  PT5M33S         hd   false           Friday 0 days 00:05:33
#
#    tagCount
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# # Data Analysis Section
# Using seaborn and matplotlib

# %% [markdown]
# ### Best Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False))
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/10000) + 'K'))

# %% [markdown]
# ### Worst Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True))
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/10000) + 'K'))

# %% [markdown]
# ### View Distribution
