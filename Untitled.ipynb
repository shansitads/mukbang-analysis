# %% [markdown]
# # Mukbang Channels Data Analysis
#
# Preprocessing, enriching and performing exploratory analysis on data on Mukbang channels using Youtube API

# %%
import pandas as pd
import numpy as np

from googleapiclient.discovery import build
from IPython.display import JSON

from functions import *

# Data visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import isodate

# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %%
api_key = 'AIzaSyDQ-X7Xj1-d3rr4Mj9t8WqcyOA9YGjaMdE'

channel_ids = ['UCo9ZZ04kIhN_8xGxvnjaduQ', # Stephanie Soo
               'UCp4LfMtDfoa29kTlLnqQ5Mg', # SAS-ASMR
               'UCkS6mJ0i2oMdHEdR-Jpw9Ug', # Hyuneeeats
               'UCoaegtPODTjRaaQdEND2m4Q', # NE Let's Eat
               'UCI78AdiI6f7VKhqW1i4B3Rw', # Zach Choi
               'UCNopoBpPj8RUebuv5Ds5Cqw', # Veronica Wang
              ]

# %%
# Get credentials and create an API client
# api service name: "youtube"
# api version: "v3"
youtube = build("youtube", "v3", developerKey=api_key)

# %%
# get channelName, subscriber, views, totalVideos and playlistId of all channels
channel_data = get_channel_stats(youtube, channel_ids)
channel_data
# Out:
#       channelName subscribers       views totalVideos  \
# 0  Zach Choi ASMR    14700000  2670905752         694
# 1   Veronica Wang     1900000   358582096         234
# 2   N.E Let's Eat     3730000  1101281440        1316
# 3      hyuneeEats     1700000   287762241         501
# 4   Stephanie Soo     2710000   598640158         981
# 5        SAS-ASMR     9390000  2759082774        1694
#
#                  playlistId
# 0  UUI78AdiI6f7VKhqW1i4B3Rw
# 1  UUNopoBpPj8RUebuv5Ds5Cqw
# 2  UUoaegtPODTjRaaQdEND2m4Q
# 3  UUkS6mJ0i2oMdHEdR-Jpw9Ug
# 4  UUo9ZZ04kIhN_8xGxvnjaduQ
# 5  UUp4LfMtDfoa29kTlLnqQ5Mg

# %%
# Convert count columns ('subscribers', 'views', 'totalVideos') to numeric columns in channel_data
numeric_cols = ['subscribers', 'views', 'totalVideos']
channel_data[numeric_cols] = channel_data[numeric_cols].apply(pd.to_numeric, errors='coerce')
channel_data.dtypes
# Out:
# channelName    object
# subscribers     int64
# views           int64
# totalVideos     int64
# playlistId     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='channelName', y='subscribers', data=channel_data.sort_values('subscribers', ascending=False))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
ax = sns.barplot(x='channelName', y='views', data=channel_data.sort_values('views', ascending=False))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
# Create a dataframe with video statistics and comments from all channels

video_df = pd.DataFrame()
comments_df = pd.DataFrame()

for i,c in enumerate(channel_data['channelName'].unique()):
    print("Getting video information from channel: " + c)
    playlist_id = channel_data['playlistId'][i]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_details(youtube, video_ids)

    # append video data together
    video_df = video_df.append(video_data, ignore_index=True)
# Out:
# Getting video information from channel: Zach Choi ASMR
# /var/folders/s1/s_t_60lx7k9b3wnl42xmt64r0000gp/T/ipykernel_26214/2514083758.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: Veronica Wang
# /var/folders/s1/s_t_60lx7k9b3wnl42xmt64r0000gp/T/ipykernel_26214/2514083758.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: N.E Let's Eat
# /var/folders/s1/s_t_60lx7k9b3wnl42xmt64r0000gp/T/ipykernel_26214/2514083758.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: hyuneeEats
# /var/folders/s1/s_t_60lx7k9b3wnl42xmt64r0000gp/T/ipykernel_26214/2514083758.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel
# 5422  [ASMR, SAS-ASMR, SASitTube, SassEsnacks, Binau...  2016-11-12T08:03:34Z
#
#      viewCount likeCount favouritecount commentCount  duration definition  \
# 0       707629     91970           None          549     PT31S         hd
# 1       417691     20047           None          638     PT17M         hd
# 2      1391358    133253           None          218     PT32S         hd
# 3      3729443    311051           None          474     PT32S         hd
# 4      8885267    737678           None         1054     PT54S         hd
# ...        ...       ...            ...          ...       ...        ...
# 5418    197626      None           None         None   PT16M7S         hd
# 5419    189356      None           None          161  PT13M26S         hd
# 5420    301890      None           None          316  PT16M49S         hd
# 5421    555402      None           None          910  PT12M38S         hd
# 5422    794925      None           None         3435  PT15M40S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 5418   false
# 5419   false
# 5420   false
# 5421   false
# 5422   false
#
# [5423 rows x 13 columns]

# %% [markdown]
# ## Preprocessing
# - Fix data types
# - Sort by published date
# - Add columns for future use

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouritecount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.publishedAt.sort_values().value_counts()
# Out:
# 2022-09-03T01:30:06Z    2
# 2019-07-18T17:00:01Z    2
# 2022-09-09T01:30:00Z    2
# 2019-06-05T02:00:02Z    2
# 2022-07-20T01:30:05Z    2
#                        ..
# 2019-02-28T00:27:15Z    1
# 2019-02-28T00:27:12Z    1
# 2019-02-27T21:45:50Z    1
# 2019-02-27T01:41:25Z    1
# 2022-10-15T01:30:11Z    1
# Name: publishedAt, Length: 5418, dtype: int64

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouritecount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# change numeric data from object type to numeric type
numeric_cols = ['viewCount', 'likeCount', 'favouritecount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# convert youtube duration to float
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount         float64
# likeCount         float64
# favouritecount    float64
# commentCount      float64
# duration           object
# definition         object
# caption            object
# durationSecs      float64
# dtype: object

# %% [markdown]
# ### Enriching
# #### Adding columns for future use

# %%
# Add publish day in the week
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'])
video_df['publishedDayName'] = video_df['publishedAt'].dt.day_name()

# %%
# Add number of tags
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
# Add title character length
video_df['titleLength'] = video_df['title'].apply(lambda x: len(x))

# %%
# Comments and likes per 1000 view ratio
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# %%
video_df.head()
# Out:
#       video_id    channelTitle  \
# 0  dOOOeyBAQxQ  Zach Choi ASMR
# 1  clblZzITpek  Zach Choi ASMR
# 2  ZXr8e3Xi1V8  Zach Choi ASMR
# 3  xJs8GQPKTAg  Zach Choi ASMR
# 4  ImKUlIurDQ8  Zach Choi ASMR
#
#                                                title  \
# 0            ultimate cheetos grilled cheese #shorts
# 1  ASMR MUKBANG MOZZARELLA CORN DOGS & MCDONALDS ...
# 2       mozzarella donut with marinara sauce #shorts
# 3                      fried chocolate donut #shorts
# 4                     ultimate spam sandwich #shorts
#
#                                          description  \
# 0  #shorts #mukbang #asmr #eating #asmreating  \n...
# 1  Join me on Fanhouse for exclusive content, ext...
# 2  #shorts #mukbang #asmr #eating #asmreating  \n...
# 3  #shorts #mukbang #asmr #eating #asmreating  \n...
# 4  #shorts #mukbang #asmr #eating #asmreating  \n...
#
#                                                 tags  \
# 0  [asmr,  zach choi, zachchoi, zach choi asmr, m...
# 1  [asmr,  zach choi, zachchoi, zach choi asmr, m...
# 2  [asmr,  zach choi, zachchoi, zach choi asmr, m...
# 3  [asmr,  zach choi, zachchoi, zach choi asmr, m...
# 4  [asmr,  zach choi, zachchoi, zach choi asmr, m...
#
#                 publishedAt  viewCount  likeCount  favouritecount  \
# 0 2022-10-15 01:30:11+00:00   707629.0    91970.0             NaN
# 1 2022-10-13 01:54:45+00:00   417691.0    20047.0             NaN
# 2 2022-10-13 01:30:08+00:00  1391358.0   133253.0             NaN
# 3 2022-10-12 01:30:13+00:00  3729443.0   311051.0             NaN
# 4 2022-10-11 01:30:04+00:00  8885267.0   737678.0             NaN
#
#    commentCount duration definition caption  durationSecs publishedDayName  \
# 0         549.0    PT31S         hd   false          31.0         Saturday
# 1         638.0    PT17M         hd   false        1020.0         Thursday
# 2         218.0    PT32S         hd   false          32.0         Thursday
# 3         474.0    PT32S         hd   false          32.0        Wednesday
# 4        1054.0    PT54S         hd   false          54.0          Tuesday
#
#    tagCount  titleLength   likeRatio  commentRatio
# 0        17           39  129.969235      0.775830
# 1        25           95   47.994810      1.527445
# 2        18           44   95.771901      0.156681
# 3        16           29   83.404144      0.127097
# 4        18           30   83.022604      0.118623

# %% [markdown]
# # Data Analysis Section
# Using seaborn and matplotlib

# %% [markdown]
# ### Best Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:10])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/10000) + 'K'))

# %% [markdown]
# ### Worst Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:10])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/10000) + 'K'))
# Out:
# /Users/shansita-dev/opt/anaconda3/envs/python3-8/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 10084 (\N{HEAVY BLACK HEART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/shansita-dev/opt/anaconda3/envs/python3-8/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/shansita-dev/opt/anaconda3/envs/python3-8/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 10052 (\N{SNOWFLAKE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### How are views distributed for each channel?

# %%
plt.rcParams['figure.figsize'] = (18, 6)
sns.violinplot(x = video_df['channelTitle'], y = video_df['viewCount'], palette = 'pastel');
plt.title('Views per channel', fontsize = 14)
plt.show()

# %% [markdown]
# ### Is the number of likes and comments correlated for with views?

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[0]);
sns.regplot(x = 'likeCount', y = 'viewCount', data=video_df, ax=ax[0]);

sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[1;
sns.regplot(x = 'commentCount', y = 'viewCount', data=video_df, ax=ax[1]);
])
rho_like_view = video_df[['likeCount','viewCount']].corr(method='pearson')
rho_comment_view = video_df[['commentCount','viewCount']].corr(method='pearson')

print(f'Correlation coefficient between likes and views = \n{rho_like_view}')
print(f'\nCorrelation coefficient between comments and views = \n{rho_comment_view}')

# %%
# Correlation for comment ratio and like ratio against views.

fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "likeRatio", y = "viewCount", ax=ax[0]);
sns.scatterplot(data = video_df, x = "commentRatio", y = "viewCount", ax=ax[1]);

rho_likeRatio_view = video_df[['likeCount','viewCount']].corr(method='pearson')
rho_commentRation_view = video_df[['commentRatio','viewCount']].corr(method='pearson')

print(f'Correlation coefficient between likes per 100 views and views = \n{rho_like_view}')
print(f'\nCorrelation coefficient between comments per 100 views and views = \n{rho_comment_view}')

# %% [markdown]
# ### Wordcloud for words in title

# %%
# stop_words contains common english words
stop_words = set(stopwords.words('english'))
# add channel names to stop_words
channel_words = []
for name in channel_data['channelName']:
    for word in name.split():
        channel_words.append(word)

video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

channel_words

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='Accent', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)
