# %%
import pandas as pd
import numpy as np

from googleapiclient.discovery import build
from IPython.display import JSON

from functions import *

# Data visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker

# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %%
api_key = 'AIzaSyDQ-X7Xj1-d3rr4Mj9t8WqcyOA9YGjaMdE'

channel_ids = ['UCrfaLdVUAziZq9_yRFKYuIQ']

# Get credentials and create an API client
# api service name: "youtube"
# api version: "v3"
youtube = build("youtube", "v3", developerKey=api_key)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#     channelName subscribers     views totalViews                playlistId
# 0  Drama Master      441000  86806439        165  UUrfaLdVUAziZq9_yRFKYuIQ

# %%
playlist_id = channel_stats['playlistId'][0]

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 165

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#         video_id  channelTitle  \
# 0    cIU9sy_5BgU  Drama Master
# 1    lEAuk94_0L0  Drama Master
# 2    cA_YIi0wavo  Drama Master
# 3    Y1VxrixgR60  Drama Master
# 4    _ZqEYv47o0E  Drama Master
# ..           ...           ...
# 160  pFww8v7k4dM  Drama Master
# 161  BcJveSbifHI  Drama Master
# 162  iQ2fOSpmMxw  Drama Master
# 163  ISjLPMp3dsM  Drama Master
# 164  0dk410zr1A8  Drama Master
#
#                                                  title  \
# 0                        Kdrama Golden era Vs Dark era
# 1                           Wife and Husband of Kdrama
# 2                           The adult life by k-dramas
# 3                          Kdrama : Use of smartphones
# 4                            Kdrama : Partner in crime
# ..                                                 ...
# 160  Johnny Johnny || Descendants of the sun || Kor...
# 161  Multifemale K-Drama MV || high heels ki & Ka |...
# 162                Goblin humour part 1 || dramamaster
# 163  Ishq wala love || Korean Hindi mix || high school
# 164     Boys over flowers || Main Tera Boyfriend || MV
#
#                                            description  \
# 0    Visit Fashion Chingu for Kdrama and kpop recre...
# 1    Drama names are available in the video, commen...
# 2    Visit Fashion Chingu for Kdrama and kpop recre...
# 3    Visit Fashion Chingu for Kdrama and kpop recre...
# 4    Drama names are available in the video, commen...
# ..                                                 ...
# 160  Song - Johnny Johnny from its entertainment \n...
# 161  Made by only your lovable dramamaster \nYou ca...
# 162  Clip cr goes to the owner \nDrama - goblin \nT...
# 163  Video made by - drama master \nPlease like & s...
# 164  Video by Drama Master \nDrama - boys over flow...
#
#                                                   tags           publishedAt  \
# 0                                                 None  2022-10-14T12:30:14Z
# 1                                                 None  2022-10-07T12:30:16Z
# 2                                                 None  2022-09-30T12:30:20Z
# 3                                                 None  2022-09-23T12:30:09Z
# 4                                                 None  2022-09-16T12:30:11Z
# ..                                                 ...                   ...
# 160                                               None  2018-06-03T05:56:09Z
# 161                            [Korean Hindi mix song]  2018-06-01T15:21:30Z
# 162                                               None  2018-05-06T07:12:00Z
# 163  [High school love on MV, High school MV, Kdram...  2017-10-29T04:09:45Z
# 164                            [Korean Hindi mix love]  2017-07-16T10:43:23Z
#
#     viewCount likeCount favouritecounut commentCount duration definition  \
# 0       68567      7838            None          522  PT5M55S         hd
# 1      190129     12513            None          436  PT5M24S         hd
# 2      169703     13046            None          488  PT6M12S         hd
# 3      137833     11263            None          497   PT6M6S         hd
# 4      187696     14435            None          552  PT5M25S         hd
# ..        ...       ...             ...          ...      ...        ...
# 160     44238      1446            None           50   PT3M3S         sd
# 161     76334      1470            None           48  PT3M31S         sd
# 162    368506     13393            None          261  PT4M51S         sd
# 163    229790      2958            None          154  PT3M35S         sd
# 164     18781       825            None           71  PT2M38S         sd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 160   false
# 161   false
# 162   false
# 163   false
# 164   false
#
# [165 rows x 13 columns]

# %%
video_df.isnull().any()
# Out:
# video_id           False
# channelTitle       False
# title              False
# description        False
# tags                True
# publishedAt        False
# viewCount          False
# likeCount          False
# favouritecounut     True
# commentCount       False
# duration           False
# definition         False
# caption            False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount          object
# likeCount          object
# favouritecounut    object
# commentCount       object
# duration           object
# definition         object
# caption            object
# dtype: object

# %%
# fix data types
numeric_cols = ['viewCount', 'likeCount', 'favouritecounut', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# publish day in the week
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'])
video_df['publishedDayName'] = video_df['publishedAt'].dt.day_name()

# %%
video_df
# Out:
#         video_id  channelTitle  \
# 0    cIU9sy_5BgU  Drama Master
# 1    lEAuk94_0L0  Drama Master
# 2    cA_YIi0wavo  Drama Master
# 3    Y1VxrixgR60  Drama Master
# 4    _ZqEYv47o0E  Drama Master
# ..           ...           ...
# 160  pFww8v7k4dM  Drama Master
# 161  BcJveSbifHI  Drama Master
# 162  iQ2fOSpmMxw  Drama Master
# 163  ISjLPMp3dsM  Drama Master
# 164  0dk410zr1A8  Drama Master
#
#                                                  title  \
# 0                        Kdrama Golden era Vs Dark era
# 1                           Wife and Husband of Kdrama
# 2                           The adult life by k-dramas
# 3                          Kdrama : Use of smartphones
# 4                            Kdrama : Partner in crime
# ..                                                 ...
# 160  Johnny Johnny || Descendants of the sun || Kor...
# 161  Multifemale K-Drama MV || high heels ki & Ka |...
# 162                Goblin humour part 1 || dramamaster
# 163  Ishq wala love || Korean Hindi mix || high school
# 164     Boys over flowers || Main Tera Boyfriend || MV
#
#                                            description  \
# 0    Visit Fashion Chingu for Kdrama and kpop recre...
# 1    Drama names are available in the video, commen...
# 2    Visit Fashion Chingu for Kdrama and kpop recre...
# 3    Visit Fashion Chingu for Kdrama and kpop recre...
# 4    Drama names are available in the video, commen...
# ..                                                 ...
# 160  Song - Johnny Johnny from its entertainment \n...
# 161  Made by only your lovable dramamaster \nYou ca...
# 162  Clip cr goes to the owner \nDrama - goblin \nT...
# 163  Video made by - drama master \nPlease like & s...
# 164  Video by Drama Master \nDrama - boys over flow...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 160                                               None
# 161                            [Korean Hindi mix song]
# 162                                               None
# 163  [High school love on MV, High school MV, Kdram...
# 164                            [Korean Hindi mix love]
#
#                   publishedAt  viewCount  likeCount  favouritecounut  \
# 0   2022-10-14 12:30:14+00:00    68567.0     7838.0              NaN
# 1   2022-10-07 12:30:16+00:00   190129.0    12513.0              NaN
# 2   2022-09-30 12:30:20+00:00   169703.0    13046.0              NaN
# 3   2022-09-23 12:30:09+00:00   137833.0    11263.0              NaN
# 4   2022-09-16 12:30:11+00:00   187696.0    14435.0              NaN
# ..                        ...        ...        ...              ...
# 160 2018-06-03 05:56:09+00:00    44238.0     1446.0              NaN
# 161 2018-06-01 15:21:30+00:00    76334.0     1470.0              NaN
# 162 2018-05-06 07:12:00+00:00   368506.0    13393.0              NaN
# 163 2017-10-29 04:09:45+00:00   229790.0     2958.0              NaN
# 164 2017-07-16 10:43:23+00:00    18781.0      825.0              NaN
#
#      commentCount duration definition caption publishedDayName
# 0           522.0  PT5M55S         hd   false           Friday
# 1           436.0  PT5M24S         hd   false           Friday
# 2           488.0  PT6M12S         hd   false           Friday
# 3           497.0   PT6M6S         hd   false           Friday
# 4           552.0  PT5M25S         hd   false           Friday
# ..            ...      ...        ...     ...              ...
# 160          50.0   PT3M3S         sd   false           Sunday
# 161          48.0  PT3M31S         sd   false           Friday
# 162         261.0  PT4M51S         sd   false           Sunday
# 163         154.0  PT3M35S         sd   false           Sunday
# 164          71.0  PT2M38S         sd   false           Sunday
#
# [165 rows x 14 columns]

# %%
# convert youtube duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df
# Out:
#         video_id  channelTitle  \
# 0    cIU9sy_5BgU  Drama Master
# 1    lEAuk94_0L0  Drama Master
# 2    cA_YIi0wavo  Drama Master
# 3    Y1VxrixgR60  Drama Master
# 4    _ZqEYv47o0E  Drama Master
# ..           ...           ...
# 160  pFww8v7k4dM  Drama Master
# 161  BcJveSbifHI  Drama Master
# 162  iQ2fOSpmMxw  Drama Master
# 163  ISjLPMp3dsM  Drama Master
# 164  0dk410zr1A8  Drama Master
#
#                                                  title  \
# 0                        Kdrama Golden era Vs Dark era
# 1                           Wife and Husband of Kdrama
# 2                           The adult life by k-dramas
# 3                          Kdrama : Use of smartphones
# 4                            Kdrama : Partner in crime
# ..                                                 ...
# 160  Johnny Johnny || Descendants of the sun || Kor...
# 161  Multifemale K-Drama MV || high heels ki & Ka |...
# 162                Goblin humour part 1 || dramamaster
# 163  Ishq wala love || Korean Hindi mix || high school
# 164     Boys over flowers || Main Tera Boyfriend || MV
#
#                                            description  \
# 0    Visit Fashion Chingu for Kdrama and kpop recre...
# 1    Drama names are available in the video, commen...
# 2    Visit Fashion Chingu for Kdrama and kpop recre...
# 3    Visit Fashion Chingu for Kdrama and kpop recre...
# 4    Drama names are available in the video, commen...
# ..                                                 ...
# 160  Song - Johnny Johnny from its entertainment \n...
# 161  Made by only your lovable dramamaster \nYou ca...
# 162  Clip cr goes to the owner \nDrama - goblin \nT...
# 163  Video made by - drama master \nPlease like & s...
# 164  Video by Drama Master \nDrama - boys over flow...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 160                                               None
# 161                            [Korean Hindi mix song]
# 162                                               None
# 163  [High school love on MV, High school MV, Kdram...
# 164                            [Korean Hindi mix love]
#
#                   publishedAt  viewCount  likeCount  favouritecounut  \
# 0   2022-10-14 12:30:14+00:00    68567.0     7838.0              NaN
# 1   2022-10-07 12:30:16+00:00   190129.0    12513.0              NaN
# 2   2022-09-30 12:30:20+00:00   169703.0    13046.0              NaN
# 3   2022-09-23 12:30:09+00:00   137833.0    11263.0              NaN
# 4   2022-09-16 12:30:11+00:00   187696.0    14435.0              NaN
# ..                        ...        ...        ...              ...
# 160 2018-06-03 05:56:09+00:00    44238.0     1446.0              NaN
# 161 2018-06-01 15:21:30+00:00    76334.0     1470.0              NaN
# 162 2018-05-06 07:12:00+00:00   368506.0    13393.0              NaN
# 163 2017-10-29 04:09:45+00:00   229790.0     2958.0              NaN
# 164 2017-07-16 10:43:23+00:00    18781.0      825.0              NaN
#
#      commentCount duration definition caption publishedDayName    durationSecs
# 0           522.0  PT5M55S         hd   false           Friday 0 days 00:05:55
# 1           436.0  PT5M24S         hd   false           Friday 0 days 00:05:24
# 2           488.0  PT6M12S         hd   false           Friday 0 days 00:06:12
# 3           497.0   PT6M6S         hd   false           Friday 0 days 00:06:06
# 4           552.0  PT5M25S         hd   false           Friday 0 days 00:05:25
# ..            ...      ...        ...     ...              ...             ...
# 160          50.0   PT3M3S         sd   false           Sunday 0 days 00:03:03
# 161          48.0  PT3M31S         sd   false           Friday 0 days 00:03:31
# 162         261.0  PT4M51S         sd   false           Sunday 0 days 00:04:51
# 163         154.0  PT3M35S         sd   false           Sunday 0 days 00:03:35
# 164          71.0  PT2M38S         sd   false           Sunday 0 days 00:02:38
#
# [165 rows x 15 columns]

# %%
# Add number of tags
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))
video_df
# Out:
#         video_id  channelTitle  \
# 0    cIU9sy_5BgU  Drama Master
# 1    lEAuk94_0L0  Drama Master
# 2    cA_YIi0wavo  Drama Master
# 3    Y1VxrixgR60  Drama Master
# 4    _ZqEYv47o0E  Drama Master
# ..           ...           ...
# 160  pFww8v7k4dM  Drama Master
# 161  BcJveSbifHI  Drama Master
# 162  iQ2fOSpmMxw  Drama Master
# 163  ISjLPMp3dsM  Drama Master
# 164  0dk410zr1A8  Drama Master
#
#                                                  title  \
# 0                        Kdrama Golden era Vs Dark era
# 1                           Wife and Husband of Kdrama
# 2                           The adult life by k-dramas
# 3                          Kdrama : Use of smartphones
# 4                            Kdrama : Partner in crime
# ..                                                 ...
# 160  Johnny Johnny || Descendants of the sun || Kor...
# 161  Multifemale K-Drama MV || high heels ki & Ka |...
# 162                Goblin humour part 1 || dramamaster
# 163  Ishq wala love || Korean Hindi mix || high school
# 164     Boys over flowers || Main Tera Boyfriend || MV
#
#                                            description  \
# 0    Visit Fashion Chingu for Kdrama and kpop recre...
# 1    Drama names are available in the video, commen...
# 2    Visit Fashion Chingu for Kdrama and kpop recre...
# 3    Visit Fashion Chingu for Kdrama and kpop recre...
# 4    Drama names are available in the video, commen...
# ..                                                 ...
# 160  Song - Johnny Johnny from its entertainment \n...
# 161  Made by only your lovable dramamaster \nYou ca...
# 162  Clip cr goes to the owner \nDrama - goblin \nT...
# 163  Video made by - drama master \nPlease like & s...
# 164  Video by Drama Master \nDrama - boys over flow...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 160                                               None
# 161                            [Korean Hindi mix song]
# 162                                               None
# 163  [High school love on MV, High school MV, Kdram...
# 164                            [Korean Hindi mix love]
#
#                   publishedAt  viewCount  likeCount  favouritecounut  \
# 0   2022-10-14 12:30:14+00:00    68567.0     7838.0              NaN
# 1   2022-10-07 12:30:16+00:00   190129.0    12513.0              NaN
# 2   2022-09-30 12:30:20+00:00   169703.0    13046.0              NaN
# 3   2022-09-23 12:30:09+00:00   137833.0    11263.0              NaN
# 4   2022-09-16 12:30:11+00:00   187696.0    14435.0              NaN
# ..                        ...        ...        ...              ...
# 160 2018-06-03 05:56:09+00:00    44238.0     1446.0              NaN
# 161 2018-06-01 15:21:30+00:00    76334.0     1470.0              NaN
# 162 2018-05-06 07:12:00+00:00   368506.0    13393.0              NaN
# 163 2017-10-29 04:09:45+00:00   229790.0     2958.0              NaN
# 164 2017-07-16 10:43:23+00:00    18781.0      825.0              NaN
#
#      commentCount duration definition caption publishedDayName  \
# 0           522.0  PT5M55S         hd   false           Friday
# 1           436.0  PT5M24S         hd   false           Friday
# 2           488.0  PT6M12S         hd   false           Friday
# 3           497.0   PT6M6S         hd   false           Friday
# 4           552.0  PT5M25S         hd   false           Friday
# ..            ...      ...        ...     ...              ...
# 160          50.0   PT3M3S         sd   false           Sunday
# 161          48.0  PT3M31S         sd   false           Friday
# 162         261.0  PT4M51S         sd   false           Sunday
# 163         154.0  PT3M35S         sd   false           Sunday
# 164          71.0  PT2M38S         sd   false           Sunday
#
#        durationSecs  tagCount
# 0   0 days 00:05:55         0
# 1   0 days 00:05:24         0
# 2   0 days 00:06:12         0
# 3   0 days 00:06:06         0
# 4   0 days 00:05:25         0
# ..              ...       ...
# 160 0 days 00:03:03         0
# 161 0 days 00:03:31         1
# 162 0 days 00:04:51         0
# 163 0 days 00:03:35        11
# 164 0 days 00:02:38         1
#
# [165 rows x 16 columns]

# %% [markdown]
# # Data Analysis Section
# Using seaborn and matplotlib

# %% [markdown]
# ### Best Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:10])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/10000) + 'K'))

# %% [markdown]
# ### Worst Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:10])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/10000) + 'K'))

# %% [markdown]
# ### View Distribution

# %%
sns.violinplot(video_df['channelTitle'], video_df['viewCount'])
# Out:
# /Users/shansita-dev/opt/anaconda3/envs/python3-8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ### Views vs Likes and Comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ### Word Cloud
